# %% [markdown]
# ## Построение дашборда

# %% [markdown]
# А теперь предлагаем из всех построенных на этом уроке графиков собрать ещё один дашборд.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
